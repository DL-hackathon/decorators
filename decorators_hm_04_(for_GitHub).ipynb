# %% [markdown]
# # Домашнее задание: декораторы

# %% [markdown]
# ## Импорт библиотек, установка констант

# %%
import requests
import time
import re

from random import randint

# %%
BOOK_PATH = 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %% [markdown]
# ## Задание 1

# %%
import time
from functools import wraps

# %%
def benchmark(func):
    """
    Декоратор, выводящий время, которое заняло выполнение декорируемой функции
    """
    @wraps(func)
    def wrapper(*args, **kwargs):
        start = time.perf_counter()
        result = func(*args, **kwargs)
        end = time.perf_counter()
        print(f'Время выполнения функции {func.__name__}: {end - start:.6f}')
        return result
    return wrapper

# %% [markdown]
# ## Задание 2

# %%
def logging(func):
    """
    Декоратор, который выводит параметры с которыми была вызвана функция
    """
    @wraps(func)
    def wrapper(*args, **kwargs):

      # arg_str = ', '.join(repr(arg) for arg in args)
      result = func(*args, **kwargs)
      if args:
        print(f'Функция {func.__name__} вызвана с параметрами:')
        print(f'{args}, {kwargs}')
      else:
        print(f'Функция {func.__name__} вызвана без параметров.')
      return result
    return wrapper

# %% [markdown]
# ## Задание 3

# %%
def counter(func):
    """
    Декоратор, считающий и выводящий количество вызовов декорируемой функции
    """
    @wraps(func)
    def wrapper(*args, **kwargs):
      global count
      result = func(*args, **kwargs)
      count += 1
      print(f'Функция {func.__name__} была вызвана: {count} раз')
      return result
    return wrapper

# %% [markdown]
# ## Задание 4

# %%
def memo(func):
  """
  Декоратор, запоминающий результаты исполнения функции func, чьи аргументы args должны быть хешируемыми
  """
  cache = {}
  @wraps(func)
  def fmemo(*args):
    if not args[0] in cache:
      cache[args[0]] = func(args[0])
    return cache[args[0]]
  fmemo.cache = cache
  return fmemo

# %% [markdown]
# ## Тестирование

# %%
@counter
@logging
@benchmark
def word_count(word, url=BOOK_PATH):
    """
    Функция для посчета указанного слова на html-странице
    """

    # отправляем запрос в библиотеку Gutenberg и забираем текст
    raw = requests.get(url).text

    # заменяем в тексте все небуквенные символы на пробелы
    processed_book = re.sub('[\W]+' , ' ', raw).lower()

    # считаем
    cnt = len(re.findall(word.lower(), processed_book))

    return f"Cлово {word} встречается {cnt} раз"

count = 0
print(word_count('whole'))
# Out:
# Время выполнения функции word_count: 1.055374
# Функция word_count вызвана с параметрами:
# ('whole',), {}
# Функция word_count была вызвана: 1 раз
# Cлово whole встречается 176 раз

# %%
@counter
@benchmark
def fib(n):
  if n == 0:
    return 0
  elif n == 1:
    return 1
  return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
count = 0
n = 15
print(f'{n + 1}-е число Фибоначчи равно {fib(n)}')
# Out:
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 2 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 3 раз
# Время выполнения функции fib: 0.000074
# Функция fib была вызвана: 4 раз
# Время выполнения функции fib: 0.000202
# Функция fib была вызвана: 5 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 6 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 7 раз
# Время выполнения функции fib: 0.000074
# Функция fib была вызвана: 8 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 9 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 10 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 11 раз
# Время выполнения функции fib: 0.000210
# Функция fib была вызвана: 12 раз
# Время выполнения функции fib: 0.000542
# Функция fib была вызвана: 13 раз
# Время выполнения функции fib: 0.000677
# Функция fib была вызвана: 14 раз
# Время выполнения функции fib: 0.000941
# Функция fib была вызвана: 15 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 16 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 17 раз
# Время выполнения функции fib: 0.000062
# Функция fib была вызвана: 18 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 19 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 20 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 21 раз
# Время выполнения функции fib: 0.000068
# Функция fib была вызвана: 22 раз
# Время выполнения функции fib: 0.000140
# Функция fib была вызвана: 23 раз
# Время выполнения функции fib: 0.000264
# Функция fib была вызвана: 24 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 25 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 26 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 27 раз
# Время выполнения функции fib: 0.000065
# Функция fib была вызвана: 28 раз
# Время выполнения функции fib: 0.000131
# Функция fib была вызвана: 29 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 30 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 31 раз
# Время выполнения функции fib: 0.000063
# Функция fib была вызвана: 32 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 33 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 34 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 35 раз
# Время выполнения функции fib: 0.000066
# Функция fib была вызвана: 36 раз
# Время выполнения функции fib: 0.000127
# Функция fib была вызвана: 37 раз
# Время выполнения функции fib: 0.000282
# Функция fib была вызвана: 38 раз
# Время выполнения функции fib: 0.000482
# Функция fib была вызвана: 39 раз
# Время выполнения функции fib: 0.000809
# Функция fib была вызвана: 40 раз
# Время выполнения функции fib: 0.001820
# Функция fib была вызвана: 41 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 42 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 43 раз
# Время выполнения функции fib: 0.000063
# Функция fib была вызвана: 44 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 45 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 46 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 47 раз
# Время выполнения функции fib: 0.000253
# Функция fib была вызвана: 48 раз
# Время выполнения функции fib: 0.000335
# Функция fib была вызвана: 49 раз
# Время выполнения функции fib: 0.000461
# Функция fib была вызвана: 50 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 51 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 52 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 53 раз
# Время выполнения функции fib: 0.000063
# Функция fib была вызвана: 54 раз
# Время выполнения функции fib: 0.000128
# Функция fib была вызвана: 55 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 56 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 57 раз
# Время выполнения функции fib: 0.000062
# Функция fib была вызвана: 58 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 59 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 60 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 61 раз
# Время выполнения функции fib: 0.000077
# Функция fib была вызвана: 62 раз
# Время выполнения функции fib: 0.000140
# Функция fib была вызвана: 63 раз
# Время выполнения функции fib: 0.000264
# Функция fib была вызвана: 64 раз
# Время выполнения функции fib: 0.000455
# Функция fib была вызвана: 65 раз
# Время выполнения функции fib: 0.000978
# Функция fib была вызвана: 66 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 67 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 68 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 69 раз
# Время выполнения функции fib: 0.000063
# Функция fib была вызвана: 70 раз
# Время выполнения функции fib: 0.000126
# Функция fib была вызвана: 71 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 72 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 73 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 74 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 75 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 76 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 77 раз
# Время выполнения функции fib: 0.000077
# Функция fib была вызвана: 78 раз
# Время выполнения функции fib: 0.000140
# Функция fib была вызвана: 79 раз
# Время выполнения функции fib: 0.000265
# Функция fib была вызвана: 80 раз
# Время выполнения функции fib: 0.000454
# Функция fib была вызвана: 81 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 82 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 83 раз
# Время выполнения функции fib: 0.000081
# Функция fib была вызвана: 84 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 85 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 86 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 87 раз
# Время выполнения функции fib: 0.000064
# Функция fib была вызвана: 88 раз
# Время выполнения функции fib: 0.000127
# Функция fib была вызвана: 89 раз
# Время выполнения функции fib: 0.000275
# Функция fib была вызвана: 90 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 91 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 92 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 93 раз
# Время выполнения функции fib: 0.000065
# Функция fib была вызвана: 94 раз
# Время выполнения функции fib: 0.000200
# Функция fib была вызвана: 95 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 96 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 97 раз
# Время выполнения функции fib: 0.000290
# Функция fib была вызвана: 98 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 99 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 100 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 101 раз
# Время выполнения функции fib: 0.000064
# Функция fib была вызвана: 102 раз
# Время выполнения функции fib: 0.000131
# Функция fib была вызвана: 103 раз
# Время выполнения функции fib: 0.000486
# Функция fib была вызвана: 104 раз
# Время выполнения функции fib: 0.000953
# Функция fib была вызвана: 105 раз
# Время выполнения функции fib: 0.001297
# Функция fib была вызвана: 106 раз
# Время выполнения функции fib: 0.001816
# Функция fib была вызвана: 107 раз
# Время выполнения функции fib: 0.002879
# Функция fib была вызвана: 108 раз
# Время выполнения функции fib: 0.004776
# Функция fib была вызвана: 109 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 110 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 111 раз
# Время выполнения функции fib: 0.000068
# Функция fib была вызвана: 112 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 113 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 114 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 115 раз
# Время выполнения функции fib: 0.000063
# Функция fib была вызвана: 116 раз
# Время выполнения функции fib: 0.000125
# Функция fib была вызвана: 117 раз
# Время выполнения функции fib: 0.000253
# Функция fib была вызвана: 118 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 119 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 120 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 121 раз
# Время выполнения функции fib: 0.000074
# Функция fib была вызвана: 122 раз
# Время выполнения функции fib: 0.000136
# Функция fib была вызвана: 123 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 124 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 125 раз
# Время выполнения функции fib: 0.000066
# Функция fib была вызвана: 126 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 127 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 128 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 129 раз
# Время выполнения функции fib: 0.000064
# Функция fib была вызвана: 130 раз
# Время выполнения функции fib: 0.000128
# Функция fib была вызвана: 131 раз
# Время выполнения функции fib: 0.000259
# Функция fib была вызвана: 132 раз
# Время выполнения функции fib: 0.000462
# Функция fib была вызвана: 133 раз
# Время выполнения функции fib: 0.000779
# Функция fib была вызвана: 134 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 135 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 136 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 137 раз
# Время выполнения функции fib: 0.000066
# Функция fib была вызвана: 138 раз
# Время выполнения функции fib: 0.000216
# Функция fib была вызвана: 139 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 140 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 141 раз
# Время выполнения функции fib: 0.000079
# Функция fib была вызвана: 142 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 143 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 144 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 145 раз
# Время выполнения функции fib: 0.000100
# Функция fib была вызвана: 146 раз
# Время выполнения функции fib: 0.000207
# Функция fib была вызвана: 147 раз
# Время выполнения функции fib: 0.000384
# Функция fib была вызвана: 148 раз
# Время выполнения функции fib: 0.000680
# Функция fib была вызвана: 149 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 150 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 151 раз
# Время выполнения функции fib: 0.009635
# Функция fib была вызвана: 152 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 153 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 154 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 155 раз
# Время выполнения функции fib: 0.000102
# Функция fib была вызвана: 156 раз
# Время выполнения функции fib: 0.000194
# Функция fib была вызвана: 157 раз
# Время выполнения функции fib: 0.010230
# Функция fib была вызвана: 158 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 159 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 160 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 161 раз
# Время выполнения функции fib: 0.000106
# Функция fib была вызвана: 162 раз
# Время выполнения функции fib: 0.000201
# Функция fib была вызвана: 163 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 164 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 165 раз
# Время выполнения функции fib: 0.000094
# Функция fib была вызвана: 166 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 167 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 168 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 169 раз
# Время выполнения функции fib: 0.000094
# Функция fib была вызвана: 170 раз
# Время выполнения функции fib: 0.000191
# Функция fib была вызвана: 171 раз
# Время выполнения функции fib: 0.000375
# Функция fib была вызвана: 172 раз
# Время выполнения функции fib: 0.000669
# Функция fib была вызвана: 173 раз
# Время выполнения функции fib: 0.010991
# Функция fib была вызвана: 174 раз
# Время выполнения функции fib: 0.011770
# Функция fib была вызвана: 175 раз
# Время выполнения функции fib: 0.012628
# Функция fib была вызвана: 176 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 177 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 178 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 179 раз
# Время выполнения функции fib: 0.000090
# Функция fib была вызвана: 180 раз
# Время выполнения функции fib: 0.000182
# Функция fib была вызвана: 181 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 182 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 183 раз
# Время выполнения функции fib: 0.000106
# Функция fib была вызвана: 184 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 185 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 186 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 187 раз
# Время выполнения функции fib: 0.000093
# Функция fib была вызвана: 188 раз
# Время выполнения функции fib: 0.000186
# Функция fib была вызвана: 189 раз
# Время выполнения функции fib: 0.000385
# Функция fib была вызвана: 190 раз
# Время выполнения функции fib: 0.017565
# Функция fib была вызвана: 191 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 192 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 193 раз
# Время выполнения функции fib: 0.000070
# Функция fib была вызвана: 194 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 195 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 196 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 197 раз
# Время выполнения функции fib: 0.000078
# Функция fib была вызвана: 198 раз
# Время выполнения функции fib: 0.000143
# Функция fib была вызвана: 199 раз
# Время выполнения функции fib: 0.000277
# Функция fib была вызвана: 200 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 201 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 202 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 203 раз
# Время выполнения функции fib: 0.000065
# Функция fib была вызвана: 204 раз
# Время выполнения функции fib: 0.000129
# Функция fib была вызвана: 205 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 206 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 207 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 208 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 209 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 210 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 211 раз
# Время выполнения функции fib: 0.000266
# Функция fib была вызвана: 212 раз
# Время выполнения функции fib: 0.000579
# Функция fib была вызвана: 213 раз
# Время выполнения функции fib: 0.001219
# Функция fib была вызвана: 214 раз
# Время выполнения функции fib: 0.001419
# Функция fib была вызвана: 215 раз
# Время выполнения функции fib: 0.001952
# Функция fib была вызвана: 216 раз
# Время выполнения функции fib: 0.019609
# Функция fib была вызвана: 217 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 218 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 219 раз
# Время выполнения функции fib: 0.000102
# Функция fib была вызвана: 220 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 221 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 222 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 223 раз
# Время выполнения функции fib: 0.000243
# Функция fib была вызвана: 224 раз
# Время выполнения функции fib: 0.000310
# Функция fib была вызвана: 225 раз
# Время выполнения функции fib: 0.000861
# Функция fib была вызвана: 226 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 227 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 228 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 229 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 230 раз
# Время выполнения функции fib: 0.000127
# Функция fib была вызвана: 231 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 232 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 233 раз
# Время выполнения функции fib: 0.000070
# Функция fib была вызвана: 234 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 235 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 236 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 237 раз
# Время выполнения функции fib: 0.000061
# Функция fib была вызвана: 238 раз
# Время выполнения функции fib: 0.000120
# Функция fib была вызвана: 239 раз
# Время выполнения функции fib: 0.000251
# Функция fib была вызвана: 240 раз
# Время выполнения функции fib: 0.000437
# Функция fib была вызвана: 241 раз
# Время выполнения функции fib: 0.001364
# Функция fib была вызвана: 242 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 243 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 244 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 245 раз
# Время выполнения функции fib: 0.000157
# Функция fib была вызвана: 246 раз
# Время выполнения функции fib: 0.000241
# Функция fib была вызвана: 247 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 248 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 249 раз
# Время выполнения функции fib: 0.000066
# Функция fib была вызвана: 250 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 251 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 252 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 253 раз
# Время выполнения функции fib: 0.000066
# Функция fib была вызвана: 254 раз
# Время выполнения функции fib: 0.000140
# Функция fib была вызвана: 255 раз
# Время выполнения функции fib: 0.000269
# Функция fib была вызвана: 256 раз
# Время выполнения функции fib: 0.000571
# Функция fib была вызвана: 257 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 258 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 259 раз
# Время выполнения функции fib: 0.000073
# Функция fib была вызвана: 260 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 261 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 262 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 263 раз
# Время выполнения функции fib: 0.000061
# Функция fib была вызвана: 264 раз
# Время выполнения функции fib: 0.000122
# Функция fib была вызвана: 265 раз
# Время выполнения функции fib: 0.000254
# Функция fib была вызвана: 266 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 267 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 268 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 269 раз
# Время выполнения функции fib: 0.000056
# Функция fib была вызвана: 270 раз
# Время выполнения функции fib: 0.000116
# Функция fib была вызвана: 271 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 272 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 273 раз
# Время выполнения функции fib: 0.000059
# Функция fib была вызвана: 274 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 275 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 276 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 277 раз
# Время выполнения функции fib: 0.000219
# Функция fib была вызвана: 278 раз
# Время выполнения функции fib: 0.000282
# Функция fib была вызвана: 279 раз
# Время выполнения функции fib: 0.000482
# Функция fib была вызвана: 280 раз
# Время выполнения функции fib: 0.000755
# Функция fib была вызвана: 281 раз
# Время выполнения функции fib: 0.001145
# Функция fib была вызвана: 282 раз
# Время выполнения функции fib: 0.001782
# Функция fib была вызвана: 283 раз
# Время выполнения функции fib: 0.003207
# Функция fib была вызвана: 284 раз
# Время выполнения функции fib: 0.023034
# Функция fib была вызвана: 285 раз
# Время выполнения функции fib: 0.035740
# Функция fib была вызвана: 286 раз
# Время выполнения функции fib: 0.040578
# Функция fib была вызвана: 287 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 288 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 289 раз
# Время выполнения функции fib: 0.000041
# Функция fib была вызвана: 290 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 291 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 292 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 293 раз
# Время выполнения функции fib: 0.000076
# Функция fib была вызвана: 294 раз
# Время выполнения функции fib: 0.000137
# Функция fib была вызвана: 295 раз
# Время выполнения функции fib: 0.000240
# Функция fib была вызвана: 296 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 297 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 298 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 299 раз
# Время выполнения функции fib: 0.000087
# Функция fib была вызвана: 300 раз
# Время выполнения функции fib: 0.000175
# Функция fib была вызвана: 301 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 302 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 303 раз
# Время выполнения функции fib: 0.057687
# Функция fib была вызвана: 304 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 305 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 306 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 307 раз
# Время выполнения функции fib: 0.000091
# Функция fib была вызвана: 308 раз
# Время выполнения функции fib: 0.000185
# Функция fib была вызвана: 309 раз
# Время выполнения функции fib: 0.058056
# Функция fib была вызвана: 310 раз
# Время выполнения функции fib: 0.058319
# Функция fib была вызвана: 311 раз
# Время выполнения функции fib: 0.058646
# Функция fib была вызвана: 312 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 313 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 314 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 315 раз
# Время выполнения функции fib: 0.000088
# Функция fib была вызвана: 316 раз
# Время выполнения функции fib: 0.000182
# Функция fib была вызвана: 317 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 318 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 319 раз
# Время выполнения функции fib: 0.000085
# Функция fib была вызвана: 320 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 321 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 322 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 323 раз
# Время выполнения функции fib: 0.000102
# Функция fib была вызвана: 324 раз
# Время выполнения функции fib: 0.000189
# Функция fib была вызвана: 325 раз
# Время выполнения функции fib: 0.000359
# Функция fib была вызвана: 326 раз
# Время выполнения функции fib: 0.000626
# Функция fib была вызвана: 327 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 328 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 329 раз
# Время выполнения функции fib: 0.000087
# Функция fib была вызвана: 330 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 331 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 332 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 333 раз
# Время выполнения функции fib: 0.000086
# Функция fib была вызвана: 334 раз
# Время выполнения функции fib: 0.000818
# Функция fib была вызвана: 335 раз
# Время выполнения функции fib: 0.001031
# Функция fib была вызвана: 336 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 337 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 338 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 339 раз
# Время выполнения функции fib: 0.000089
# Функция fib была вызвана: 340 раз
# Время выполнения функции fib: 0.000178
# Функция fib была вызвана: 341 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 342 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 343 раз
# Время выполнения функции fib: 0.000087
# Функция fib была вызвана: 344 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 345 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 346 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 347 раз
# Время выполнения функции fib: 0.000091
# Функция fib была вызвана: 348 раз
# Время выполнения функции fib: 0.000181
# Функция fib была вызвана: 349 раз
# Время выполнения функции fib: 0.000360
# Функция fib была вызвана: 350 раз
# Время выполнения функции fib: 0.000625
# Функция fib была вызвана: 351 раз
# Время выполнения функции fib: 0.001756
# Функция fib была вызвана: 352 раз
# Время выполнения функции fib: 0.002470
# Функция fib была вызвана: 353 раз
# Время выполнения функции fib: 0.061209
# Функция fib была вызвана: 354 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 355 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 356 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 357 раз
# Время выполнения функции fib: 0.000089
# Функция fib была вызвана: 358 раз
# Время выполнения функции fib: 0.000176
# Функция fib была вызвана: 359 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 360 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 361 раз
# Время выполнения функции fib: 0.000092
# Функция fib была вызвана: 362 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 363 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 364 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 365 раз
# Время выполнения функции fib: 0.000085
# Функция fib была вызвана: 366 раз
# Время выполнения функции fib: 0.000171
# Функция fib была вызвана: 367 раз
# Время выполнения функции fib: 0.000350
# Функция fib была вызвана: 368 раз
# Время выполнения функции fib: 0.000673
# Функция fib была вызвана: 369 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 370 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 371 раз
# Время выполнения функции fib: 0.000087
# Функция fib была вызвана: 372 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 373 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 374 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 375 раз
# Время выполнения функции fib: 0.000093
# Функция fib была вызвана: 376 раз
# Время выполнения функции fib: 0.000206
# Функция fib была вызвана: 377 раз
# Время выполнения функции fib: 0.001424
# Функция fib была вызвана: 378 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 379 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 380 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 381 раз
# Время выполнения функции fib: 0.000086
# Функция fib была вызвана: 382 раз
# Время выполнения функции fib: 0.000173
# Функция fib была вызвана: 383 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 384 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 385 раз
# Время выполнения функции fib: 0.000093
# Функция fib была вызвана: 386 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 387 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 388 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 389 раз
# Время выполнения функции fib: 0.000085
# Функция fib была вызвана: 390 раз
# Время выполнения функции fib: 0.000172
# Функция fib была вызвана: 391 раз
# Время выполнения функции fib: 0.000353
# Функция fib была вызвана: 392 раз
# Время выполнения функции fib: 0.000610
# Функция fib была вызвана: 393 раз
# Время выполнения функции fib: 0.002133
# Функция fib была вызвана: 394 раз
# Время выполнения функции fib: 0.002891
# Функция fib была вызвана: 395 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 396 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 397 раз
# Время выполнения функции fib: 0.000087
# Функция fib была вызвана: 398 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 399 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 400 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 401 раз
# Время выполнения функции fib: 0.000086
# Функция fib была вызвана: 402 раз
# Время выполнения функции fib: 0.000172
# Функция fib была вызвана: 403 раз
# Время выполнения функции fib: 0.000357
# Функция fib была вызвана: 404 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 405 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 406 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 407 раз
# Время выполнения функции fib: 0.000087
# Функция fib была вызвана: 408 раз
# Время выполнения функции fib: 0.000169
# Функция fib была вызвана: 409 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 410 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 411 раз
# Время выполнения функции fib: 0.000096
# Функция fib была вызвана: 412 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 413 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 414 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 415 раз
# Время выполнения функции fib: 0.000087
# Функция fib была вызвана: 416 раз
# Время выполнения функции fib: 0.000172
# Функция fib была вызвана: 417 раз
# Время выполнения функции fib: 0.000364
# Функция fib была вызвана: 418 раз
# Время выполнения функции fib: 0.004195
# Функция fib была вызвана: 419 раз
# Время выполнения функции fib: 0.004636
# Функция fib была вызвана: 420 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 421 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 422 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 423 раз
# Время выполнения функции fib: 0.000086
# Функция fib была вызвана: 424 раз
# Время выполнения функции fib: 0.000171
# Функция fib была вызвана: 425 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 426 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 427 раз
# Время выполнения функции fib: 0.000104
# Функция fib была вызвана: 428 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 429 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 430 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 431 раз
# Время выполнения функции fib: 0.000086
# Функция fib была вызвана: 432 раз
# Время выполнения функции fib: 0.000170
# Функция fib была вызвана: 433 раз
# Время выполнения функции fib: 0.000366
# Функция fib была вызвана: 434 раз
# Время выполнения функции fib: 0.000622
# Функция fib была вызвана: 435 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 436 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 437 раз
# Время выполнения функции fib: 0.000086
# Функция fib была вызвана: 438 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 439 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 440 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 441 раз
# Время выполнения функции fib: 0.000087
# Функция fib была вызвана: 442 раз
# Время выполнения функции fib: 0.000174
# Функция fib была вызвана: 443 раз
# Время выполнения функции fib: 0.000345
# Функция fib была вызвана: 444 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 445 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 446 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 447 раз
# Время выполнения функции fib: 0.000086
# Функция fib была вызвана: 448 раз
# Время выполнения функции fib: 0.000184
# Функция fib была вызвана: 449 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 450 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 451 раз
# Время выполнения функции fib: 0.000092
# Функция fib была вызвана: 452 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 453 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 454 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 455 раз
# Время выполнения функции fib: 0.000089
# Функция fib была вызвана: 456 раз
# Время выполнения функции fib: 0.000176
# Функция fib была вызвана: 457 раз
# Время выполнения функции fib: 0.000355
# Функция fib была вызвана: 458 раз
# Время выполнения функции fib: 0.000627
# Функция fib была вызвана: 459 раз
# Время выполнения функции fib: 0.001057
# Функция fib была вызвана: 460 раз
# Время выполнения функции fib: 0.001764
# Функция fib была вызвана: 461 раз
# Время выполнения функции fib: 0.006487
# Функция fib была вызвана: 462 раз
# Время выполнения функции fib: 0.009468
# Функция fib была вызвана: 463 раз
# Время выполнения функции fib: 0.070766
# Функция fib была вызвана: 464 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 465 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 466 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 467 раз
# Время выполнения функции fib: 0.000782
# Функция fib была вызвана: 468 раз
# Время выполнения функции fib: 0.000877
# Функция fib была вызвана: 469 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 470 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 471 раз
# Время выполнения функции fib: 0.000090
# Функция fib была вызвана: 472 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 473 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 474 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 475 раз
# Время выполнения функции fib: 0.000103
# Функция fib была вызвана: 476 раз
# Время выполнения функции fib: 0.000282
# Функция fib была вызвана: 477 раз
# Время выполнения функции fib: 0.000459
# Функция fib была вызвана: 478 раз
# Время выполнения функции fib: 0.001428
# Функция fib была вызвана: 479 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 480 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 481 раз
# Время выполнения функции fib: 0.000088
# Функция fib была вызвана: 482 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 483 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 484 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 485 раз
# Время выполнения функции fib: 0.000088
# Функция fib была вызвана: 486 раз
# Время выполнения функции fib: 0.000174
# Функция fib была вызвана: 487 раз
# Время выполнения функции fib: 0.000348
# Функция fib была вызвана: 488 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 489 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 490 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 491 раз
# Время выполнения функции fib: 0.000086
# Функция fib была вызвана: 492 раз
# Время выполнения функции fib: 0.000174
# Функция fib была вызвана: 493 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 494 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 495 раз
# Время выполнения функции fib: 0.000089
# Функция fib была вызвана: 496 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 497 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 498 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 499 раз
# Время выполнения функции fib: 0.000094
# Функция fib была вызвана: 500 раз
# Время выполнения функции fib: 0.000184
# Функция fib была вызвана: 501 раз
# Время выполнения функции fib: 0.000358
# Функция fib была вызвана: 502 раз
# Время выполнения функции fib: 0.000618
# Функция fib была вызвана: 503 раз
# Время выполнения функции fib: 0.001051
# Функция fib была вызвана: 504 раз
# Время выполнения функции fib: 0.002565
# Функция fib была вызвана: 505 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 506 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 507 раз
# Время выполнения функции fib: 0.000097
# Функция fib была вызвана: 508 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 509 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 510 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 511 раз
# Время выполнения функции fib: 0.000082
# Функция fib была вызвана: 512 раз
# Время выполнения функции fib: 0.000161
# Функция fib была вызвана: 513 раз
# Время выполнения функции fib: 0.000340
# Функция fib была вызвана: 514 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 515 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 516 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 517 раз
# Время выполнения функции fib: 0.000083
# Функция fib была вызвана: 518 раз
# Время выполнения функции fib: 0.000183
# Функция fib была вызвана: 519 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 520 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 521 раз
# Время выполнения функции fib: 0.000094
# Функция fib была вызвана: 522 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 523 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 524 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 525 раз
# Время выполнения функции fib: 0.000133
# Функция fib была вызвана: 526 раз
# Время выполнения функции fib: 0.000222
# Функция fib была вызвана: 527 раз
# Время выполнения функции fib: 0.000429
# Функция fib была вызвана: 528 раз
# Время выполнения функции fib: 0.000695
# Функция fib была вызвана: 529 раз
# Время выполнения функции fib: 0.001117
# Функция fib была вызвана: 530 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 531 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 532 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 533 раз
# Время выполнения функции fib: 0.000095
# Функция fib была вызвана: 534 раз
# Время выполнения функции fib: 0.000180
# Функция fib была вызвана: 535 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 536 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 537 раз
# Время выполнения функции fib: 0.000113
# Функция fib была вызвана: 538 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 539 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 540 раз
# Время выполнения функции fib: 0.000002
# Функция fib была вызвана: 541 раз
# Время выполнения функции fib: 0.000488
# Функция fib была вызвана: 542 раз
# Время выполнения функции fib: 0.000594
# Функция fib была вызвана: 543 раз
# Время выполнения функции fib: 0.000826
# Функция fib была вызвана: 544 раз
# Время выполнения функции fib: 0.060261
# Функция fib была вызвана: 545 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 546 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 547 раз
# Время выполнения функции fib: 0.000342
# Функция fib была вызвана: 548 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 549 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 550 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 551 раз
# Время выполнения функции fib: 0.000062
# Функция fib была вызвана: 552 раз
# Время выполнения функции fib: 0.000118
# Функция fib была вызвана: 553 раз
# Время выполнения функции fib: 0.000526
# Функция fib была вызвана: 554 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 555 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 556 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 557 раз
# Время выполнения функции fib: 0.000057
# Функция fib была вызвана: 558 раз
# Время выполнения функции fib: 0.000114
# Функция fib была вызвана: 559 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 560 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 561 раз
# Время выполнения функции fib: 0.000061
# Функция fib была вызвана: 562 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 563 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 564 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 565 раз
# Время выполнения функции fib: 0.000061
# Функция fib была вызвана: 566 раз
# Время выполнения функции fib: 0.000119
# Функция fib была вызвана: 567 раз
# Время выполнения функции fib: 0.000240
# Функция fib была вызвана: 568 раз
# Время выполнения функции fib: 0.000412
# Функция fib была вызвана: 569 раз
# Время выполнения функции fib: 0.000996
# Функция fib была вызвана: 570 раз
# Время выполнения функции fib: 0.061342
# Функция fib была вызвана: 571 раз
# Время выполнения функции fib: 0.062529
# Функция fib была вызвана: 572 раз
# Время выполнения функции fib: 0.065166
# Функция fib была вызвана: 573 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 574 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 575 раз
# Время выполнения функции fib: 0.000059
# Функция fib была вызвана: 576 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 577 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 578 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 579 раз
# Время выполнения функции fib: 0.000061
# Функция fib была вызвана: 580 раз
# Время выполнения функции fib: 0.000120
# Функция fib была вызвана: 581 раз
# Время выполнения функции fib: 0.000267
# Функция fib была вызвана: 582 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 583 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 584 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 585 раз
# Время выполнения функции fib: 0.000052
# Функция fib была вызвана: 586 раз
# Время выполнения функции fib: 0.000105
# Функция fib была вызвана: 587 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 588 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 589 раз
# Время выполнения функции fib: 0.000055
# Функция fib была вызвана: 590 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 591 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 592 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 593 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 594 раз
# Время выполнения функции fib: 0.000115
# Функция fib была вызвана: 595 раз
# Время выполнения функции fib: 0.000226
# Функция fib была вызвана: 596 раз
# Время выполнения функции fib: 0.000385
# Функция fib была вызвана: 597 раз
# Время выполнения функции fib: 0.000710
# Функция fib была вызвана: 598 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 599 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 600 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 601 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 602 раз
# Время выполнения функции fib: 0.000195
# Функция fib была вызвана: 603 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 604 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 605 раз
# Время выполнения функции fib: 0.000057
# Функция fib была вызвана: 606 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 607 раз
# Время выполнения функции fib: 0.000016
# Функция fib была вызвана: 608 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 609 раз
# Время выполнения функции fib: 0.000092
# Функция fib была вызвана: 610 раз
# Время выполнения функции fib: 0.000161
# Функция fib была вызвана: 611 раз
# Время выполнения функции fib: 0.000287
# Функция fib была вызвана: 612 раз
# Время выполнения функции fib: 0.000544
# Функция fib была вызвана: 613 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 614 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 615 раз
# Время выполнения функции fib: 0.000065
# Функция fib была вызвана: 616 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 617 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 618 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 619 раз
# Время выполнения функции fib: 0.000052
# Функция fib была вызвана: 620 раз
# Время выполнения функции fib: 0.000132
# Функция fib была вызвана: 621 раз
# Время выполнения функции fib: 0.005390
# Функция fib была вызвана: 622 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 623 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 624 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 625 раз
# Время выполнения функции fib: 0.000065
# Функция fib была вызвана: 626 раз
# Время выполнения функции fib: 0.000114
# Функция fib была вызвана: 627 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 628 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 629 раз
# Время выполнения функции fib: 0.000048
# Функция fib была вызвана: 630 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 631 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 632 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 633 раз
# Время выполнения функции fib: 0.000049
# Функция fib была вызвана: 634 раз
# Время выполнения функции fib: 0.000097
# Функция fib была вызвана: 635 раз
# Время выполнения функции fib: 0.000193
# Функция fib была вызвана: 636 раз
# Время выполнения функции fib: 0.000364
# Функция fib была вызвана: 637 раз
# Время выполнения функции fib: 0.005802
# Функция fib была вызвана: 638 раз
# Время выполнения функции fib: 0.006406
# Функция fib была вызвана: 639 раз
# Время выполнения функции fib: 0.007182
# Функция fib была вызвана: 640 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 641 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 642 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 643 раз
# Время выполнения функции fib: 0.000053
# Функция fib была вызвана: 644 раз
# Время выполнения функции fib: 0.000101
# Функция fib была вызвана: 645 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 646 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 647 раз
# Время выполнения функции fib: 0.000048
# Функция fib была вызвана: 648 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 649 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 650 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 651 раз
# Время выполнения функции fib: 0.000048
# Функция fib была вызвана: 652 раз
# Время выполнения функции fib: 0.000095
# Функция fib была вызвана: 653 раз
# Время выполнения функции fib: 0.000191
# Функция fib была вызвана: 654 раз
# Время выполнения функции fib: 0.000339
# Функция fib была вызвана: 655 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 656 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 657 раз
# Время выполнения функции fib: 0.000048
# Функция fib была вызвана: 658 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 659 раз
# ...
# Функция fib была вызвана: 1758 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1759 раз
# Время выполнения функции fib: 0.000110
# Функция fib была вызвана: 1760 раз
# Время выполнения функции fib: 0.000164
# Функция fib была вызвана: 1761 раз
# Время выполнения функции fib: 0.000286
# Функция fib была вызвана: 1762 раз
# Время выполнения функции fib: 0.000468
# Функция fib была вызвана: 1763 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1764 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1765 раз
# Время выполнения функции fib: 0.000053
# Функция fib была вызвана: 1766 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1767 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1768 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1769 раз
# Время выполнения функции fib: 0.000054
# Функция fib была вызвана: 1770 раз
# Время выполнения функции fib: 0.000107
# Функция fib была вызвана: 1771 раз
# Время выполнения функции fib: 0.000213
# Функция fib была вызвана: 1772 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1773 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1774 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1775 раз
# Время выполнения функции fib: 0.000056
# Функция fib была вызвана: 1776 раз
# Время выполнения функции fib: 0.000109
# Функция fib была вызвана: 1777 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1778 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1779 раз
# Время выполнения функции fib: 0.000053
# Функция fib была вызвана: 1780 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1781 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1782 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1783 раз
# Время выполнения функции fib: 0.000055
# Функция fib была вызвана: 1784 раз
# Время выполнения функции fib: 0.012369
# Функция fib была вызвана: 1785 раз
# Время выполнения функции fib: 0.012488
# Функция fib была вызвана: 1786 раз
# Время выполнения функции fib: 0.012653
# Функция fib была вызвана: 1787 раз
# Время выполнения функции fib: 0.012921
# Функция fib была вызвана: 1788 раз
# Время выполнения функции fib: 0.013445
# Функция fib была вызвана: 1789 раз
# Время выполнения функции fib: 0.014142
# Функция fib была вызвана: 1790 раз
# Время выполнения функции fib: 0.015421
# Функция fib была вызвана: 1791 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1792 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1793 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 1794 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1795 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1796 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1797 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 1798 раз
# Время выполнения функции fib: 0.000116
# Функция fib была вызвана: 1799 раз
# Время выполнения функции fib: 0.000232
# Функция fib была вызвана: 1800 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1801 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1802 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1803 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 1804 раз
# Время выполнения функции fib: 0.000116
# Функция fib была вызвана: 1805 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1806 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1807 раз
# Время выполнения функции fib: 0.000059
# Функция fib была вызвана: 1808 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1809 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1810 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1811 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 1812 раз
# Время выполнения функции fib: 0.000135
# Функция fib была вызвана: 1813 раз
# Время выполнения функции fib: 0.000251
# Функция fib была вызвана: 1814 раз
# Время выполнения функции fib: 0.000434
# Функция fib была вызвана: 1815 раз
# Время выполнения функции fib: 0.000725
# Функция fib была вызвана: 1816 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1817 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1818 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1819 раз
# Время выполнения функции fib: 0.000057
# Функция fib была вызвана: 1820 раз
# Время выполнения функции fib: 0.000113
# Функция fib была вызвана: 1821 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1822 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1823 раз
# Время выполнения функции fib: 0.000064
# Функция fib была вызвана: 1824 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1825 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1826 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1827 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 1828 раз
# Время выполнения функции fib: 0.000116
# Функция fib была вызвана: 1829 раз
# Время выполнения функции fib: 0.000237
# Функция fib была вызвана: 1830 раз
# Время выполнения функции fib: 0.000408
# Функция fib была вызвана: 1831 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1832 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1833 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 1834 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1835 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1836 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1837 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 1838 раз
# Время выполнения функции fib: 0.000114
# Функция fib была вызвана: 1839 раз
# Время выполнения функции fib: 0.000230
# Функция fib была вызвана: 1840 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1841 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1842 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1843 раз
# Время выполнения функции fib: 0.000162
# Функция fib была вызвана: 1844 раз
# Время выполнения функции fib: 0.000221
# Функция fib была вызвана: 1845 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1846 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1847 раз
# Время выполнения функции fib: 0.000059
# Функция fib была вызвана: 1848 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1849 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1850 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1851 раз
# Время выполнения функции fib: 0.000061
# Функция fib была вызвана: 1852 раз
# Время выполнения функции fib: 0.000118
# Функция fib была вызвана: 1853 раз
# Время выполнения функции fib: 0.000318
# Функция fib была вызвана: 1854 раз
# Время выполнения функции fib: 0.000609
# Функция fib была вызвана: 1855 раз
# Время выполнения функции fib: 0.000900
# Функция fib была вызвана: 1856 раз
# Время выполнения функции fib: 0.001367
# Функция fib была вызвана: 1857 раз
# Время выполнения функции fib: 0.002152
# Функция fib была вызвана: 1858 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1859 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1860 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1861 раз
# Время выполнения функции fib: 0.000054
# Функция fib была вызвана: 1862 раз
# Время выполнения функции fib: 0.000111
# Функция fib была вызвана: 1863 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1864 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1865 раз
# Время выполнения функции fib: 0.000056
# Функция fib была вызвана: 1866 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1867 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1868 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1869 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 1870 раз
# Время выполнения функции fib: 0.000135
# Функция fib была вызвана: 1871 раз
# Время выполнения функции fib: 0.000247
# Функция fib была вызвана: 1872 раз
# Время выполнения функции fib: 0.000416
# Функция fib была вызвана: 1873 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1874 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1875 раз
# Время выполнения функции fib: 0.000065
# Функция fib была вызвана: 1876 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1877 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1878 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1879 раз
# Время выполнения функции fib: 0.000094
# Функция fib была вызвана: 1880 раз
# Время выполнения функции fib: 0.000159
# Функция fib была вызвана: 1881 раз
# Время выполнения функции fib: 0.000283
# Функция fib была вызвана: 1882 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1883 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1884 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1885 раз
# Время выполнения функции fib: 0.000056
# Функция fib была вызвана: 1886 раз
# Время выполнения функции fib: 0.000114
# Функция fib была вызвана: 1887 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1888 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1889 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 1890 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1891 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1892 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1893 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 1894 раз
# Время выполнения функции fib: 0.000117
# Функция fib была вызвана: 1895 раз
# Время выполнения функции fib: 0.000236
# Функция fib была вызвана: 1896 раз
# Время выполнения функции fib: 0.000408
# Функция fib была вызвана: 1897 раз
# Время выполнения функции fib: 0.000752
# Функция fib была вызвана: 1898 раз
# Время выполнения функции fib: 0.001227
# Функция fib была вызвана: 1899 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1900 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1901 раз
# Время выполнения функции fib: 0.000154
# Функция fib была вызвана: 1902 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1903 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1904 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1905 раз
# Время выполнения функции fib: 0.000069
# Функция fib была вызвана: 1906 раз
# Время выполнения функции fib: 0.000133
# Функция fib была вызвана: 1907 раз
# Время выполнения функции fib: 0.000346
# Функция fib была вызвана: 1908 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1909 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1910 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1911 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 1912 раз
# Время выполнения функции fib: 0.000117
# Функция fib была вызвана: 1913 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1914 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1915 раз
# Время выполнения функции fib: 0.000070
# Функция fib была вызвана: 1916 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1917 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1918 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1919 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 1920 раз
# Время выполнения функции fib: 0.000114
# Функция fib была вызвана: 1921 раз
# Время выполнения функции fib: 0.000241
# Функция fib была вызвана: 1922 раз
# Время выполнения функции fib: 0.000435
# Функция fib была вызвана: 1923 раз
# Время выполнения функции fib: 0.000839
# Функция fib была вызвана: 1924 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1925 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1926 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1927 раз
# Время выполнения функции fib: 0.000059
# Функция fib была вызвана: 1928 раз
# Время выполнения функции fib: 0.000117
# Функция fib была вызвана: 1929 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1930 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1931 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 1932 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1933 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1934 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1935 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 1936 раз
# Время выполнения функции fib: 0.000126
# Функция fib была вызвана: 1937 раз
# Время выполнения функции fib: 0.000269
# Функция fib была вызвана: 1938 раз
# Время выполнения функции fib: 0.000442
# Функция fib была вызвана: 1939 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1940 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1941 раз
# Время выполнения функции fib: 0.000059
# Функция fib была вызвана: 1942 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1943 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1944 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1945 раз
# Время выполнения функции fib: 0.000056
# Функция fib была вызвана: 1946 раз
# Время выполнения функции fib: 0.000112
# Функция fib была вызвана: 1947 раз
# Время выполнения функции fib: 0.000229
# Функция fib была вызвана: 1948 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1949 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1950 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1951 раз
# Время выполнения функции fib: 0.000059
# Функция fib была вызвана: 1952 раз
# Время выполнения функции fib: 0.000118
# Функция fib была вызвана: 1953 раз
# Время выполнения функции fib: 0.000000
# Функция fib была вызвана: 1954 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1955 раз
# Время выполнения функции fib: 0.000074
# Функция fib была вызвана: 1956 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1957 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1958 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 1959 раз
# Время выполнения функции fib: 0.000132
# Функция fib была вызвана: 1960 раз
# Время выполнения функции fib: 0.000192
# Функция fib была вызвана: 1961 раз
# Время выполнения функции fib: 0.000339
# Функция fib была вызвана: 1962 раз
# Время выполнения функции fib: 0.000513
# Функция fib была вызвана: 1963 раз
# Время выполнения функции fib: 0.000803
# Функция fib была вызвана: 1964 раз
# Время выполнения функции fib: 0.001303
# Функция fib была вызвана: 1965 раз
# Время выполнения функции fib: 0.002200
# Функция fib была вызвана: 1966 раз
# Время выполнения функции fib: 0.003483
# Функция fib была вызвана: 1967 раз
# Время выполнения функции fib: 0.005702
# Функция fib была вызвана: 1968 раз
# Время выполнения функции fib: 0.021180
# Функция fib была вызвана: 1969 раз
# Время выполнения функции fib: 0.039599
# Функция fib была вызвана: 1970 раз
# Время выполнения функции fib: 0.209409
# Функция fib была вызвана: 1971 раз
# Время выполнения функции fib: 0.236940
# Функция fib была вызвана: 1972 раз
# Время выполнения функции fib: 0.424032
# Функция fib была вызвана: 1973 раз
# 16-е число Фибоначчи равно 610

# %% [markdown]
# Итого:
#
# Время выполнения функции fib: 0.424032
#
# Функция fib была вызвана: 1973 раз
#
# 16-е число Фибоначчи равно 610

# %%
@counter
@benchmark
@memo
def fib(n):
  if n == 0:
    return 0
  elif n == 1:
    return 1
  return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
count = 0
print(f'{n + 1}-е число Фибоначчи равно {fib(n)}')
# Out:
# Время выполнения функции fib: 0.000002
# Функция fib была вызвана: 1 раз
# Время выполнения функции fib: 0.000002
# Функция fib была вызвана: 2 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 3 раз
# Время выполнения функции fib: 0.000060
# Функция fib была вызвана: 4 раз
# Время выполнения функции fib: 0.000172
# Функция fib была вызвана: 5 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 6 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 7 раз
# Время выполнения функции fib: 0.000055
# Функция fib была вызвана: 8 раз
# Время выполнения функции fib: 0.000283
# Функция fib была вызвана: 9 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 10 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 11 раз
# Время выполнения функции fib: 0.000055
# Функция fib была вызвана: 12 раз
# Время выполнения функции fib: 0.000394
# Функция fib была вызвана: 13 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 14 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 15 раз
# Время выполнения функции fib: 0.000055
# Функция fib была вызвана: 16 раз
# Время выполнения функции fib: 0.000505
# Функция fib была вызвана: 17 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 18 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 19 раз
# Время выполнения функции fib: 0.000058
# Функция fib была вызвана: 20 раз
# Время выполнения функции fib: 0.000621
# Функция fib была вызвана: 21 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 22 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 23 раз
# Время выполнения функции fib: 0.000057
# Функция fib была вызвана: 24 раз
# Время выполнения функции fib: 0.000735
# Функция fib была вызвана: 25 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 26 раз
# Время выполнения функции fib: 0.000001
# Функция fib была вызвана: 27 раз
# Время выполнения функции fib: 0.000056
# Функция fib была вызвана: 28 раз
# Время выполнения функции fib: 0.000848
# Функция fib была вызвана: 29 раз
# 16-е число Фибоначчи равно 610

# %% [markdown]
# Итого:
#
# Время выполнения функции fib: 0.001294
#
# Функция fib была вызвана: 29 раз
#
# 16-е число Фибоначчи равно 610

# %% [markdown]
# Таким образом, хэширование позволило сократить:
#   - время вычисления в 500 раз (0.424032 / 0.000848);
#   - число вызовов функции fib примерно в 68 раз (1973 / 29).

# %%
0.424032 / 0.000848, 1973 / 29
# Out:
# (500.0377358490566, 68.03448275862068)
